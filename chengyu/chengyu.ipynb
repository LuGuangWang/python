# %%
import pandas as pd

# %%
df = pd.read_json('idiom.json')
df[:2]
# Out:
#                    derivation  \
# 0       语出《法华经·法师功德品》下至阿鼻地狱。”
# 1  三国·魏·曹操《整齐风俗令》阿党比周，先圣所疾也。”
#
#                                              example  \
# 0               但也有少数意志薄弱的……逐步上当，终至堕入～。★《上饶集中营·炼狱杂记》
# 1  《论语·卫灵公》众恶之，必察焉；众好之，必察焉”何晏集解引三国魏王肃曰或众～，或其人特立不群...
#
#                                          explanation          pinyin  word  \
# 0  阿鼻梵语的译音，意译为无间”，即痛苦无有间断之意。常用来比喻黑暗的社会和严酷的牢狱。又比喻无...      ā bí dì yù  阿鼻地狱
# 1                                   指相互勾结，相互偏袒，结党营私。  ē dǎng bǐ zhōu  阿党比周
#
#   abbreviation
# 0         abdy
# 1         edbz

# %%
len(df)
# Out:
# 30895

# %%
df[df['word'].str.find('击肩摩') != -1]
# Out:
#                    derivation                                        example  \
# 8211  《战国策·齐策一》临淄之途，车毂击，人肩摩。”  只见这弄堂里面，熙来攘往，～；那出进的轿子，更觉络绎不绝。★清·李宝嘉《官场现形记》第八回
#
#                       explanation         pinyin  word abbreviation
# 8211  肩膀和肩膀相摩，车轮和车轮相撞。形容行人车辆往来拥挤。  gǔ jī jiān mó  毂击肩摩         gjjm

# %%
words = df.filter(items=['word'])

# %%
len(words)
# Out:
# 30895

# %%
words[:5]
# Out:
#    word
# 0  阿鼻地狱
# 1  阿党比周
# 2  阿党相为
# 3  阿狗阿猫
# 4  阿姑阿翁

# %%
words.to_csv("words.csv",index=False)

# %%
words['len'] = words['word'].apply(len)

# %%
words[:5]
# Out:
#    word  len
# 0  阿鼻地狱    4
# 1  阿党比周    4
# 2  阿党相为    4
# 3  阿狗阿猫    4
# 4  阿姑阿翁    4

# %%
words.sort_values('len',ascending=False)[:30]
# Out:
#                   word  len
# 21467  踏破铁鞋无觅处，得来全不费功夫   15
# 7873   各人自扫门前雪，莫管他家瓦上霜   15
# 10299    鸡犬之声相闻，老死不相往来   13
# 29617    只许州官放火，不许百姓点灯   13
# 19540    舍得一身剐，敢把皇帝拉下马   13
# 18146    拳头上立得人，胳膊上走得路   13
# 21920    天有不测风云，人有旦夕祸福   13
# 27095     以其人之道，还治其人之身   12
# 25277     学然后知不足，教然后知困   12
# 15258     明察秋毫之末，而不见舆薪   12
# 26729      一着被蛇咬，三年怕井绳   11
# 29616      只听楼梯响，不见人下来   11
# 19097      三十年河东，三十年河西   11
# 26140      一朝权在手，便把令来行   11
# 10202      祸兮福所倚，福兮祸所伏   11
# 28856      在人矮檐下，怎敢不低头   11
# 8756       海内存知己，天涯若比邻   11
# 29619      只要功夫深，铁杵磨成针   11
# 14306      路遥知马力，日久见人心   11
# 17293      前不见古人，后不见来者   11
# 3107       成人不自在，自在不成人   11
# 4630       淡泊以明志，宁静以致远   11
# 19476      上无片瓦，下无插针之地   11
# 27168      以小人之心，度君子之腹   11
# 14005      留得青山在，不怕没柴烧   11
# 19342      山上无老虎，猴子称大王   11
# 21893      天下本无事，庸人自扰之   11
# 96         爱之欲其生，恶之欲其死   11
# 3996       此处不留人，自有留人处   11
# 2777       长他人志气，灭自己威风   11
